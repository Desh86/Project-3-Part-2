# %%
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from sklearn.compose import make_column_selector
from tqdm.notebook import tqdm

# %%
import json
with open('/Users/user/.secret/tmdb_api.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['api-key'])

# %%
import tmdbsimple as tmdb
tmdb.API_KEY =  login['api-key']

# %%
## make a movie object using the .Movies function from tmdb
movie = tmdb.Movies('945729')

# %%
## movie objects have a .info dictionary 
info = movie.info()
info
# Out:
# {'adult': False,
#  'backdrop_path': '/kHlX3oqdD4VGaLpB8O78M25KfdS.jpg',
#  'belongs_to_collection': {'id': 735384,
#   'name': 'Hercule Poirot (Kenneth Branagh) Collection',
#   'poster_path': '/m9ypNb42ZKmwrHEsNxc329s1PI6.jpg',
#   'backdrop_path': '/rI27nF0juWNs3vwhQ8p2qUwE88F.jpg'},
#  'budget': 60000000,
#  'genres': [{'id': 9648, 'name': 'Mystery'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 80, 'name': 'Crime'}],
#  'homepage': 'https://www.20thcenturystudios.com/movies/a-haunting-in-venice',
#  'id': 945729,
#  'imdb_id': 'tt22687790',
#  'original_language': 'en',
#  'original_title': 'A Haunting in Venice',
#  'overview': 'Celebrated sleuth Hercule Poirot, now retired and living in self-imposed exile in Venice, reluctantly attends a Halloween séance at a decaying, haunted palazzo. When one of the guests is murdered, the detective is thrust into a sinister world of shadows and secrets.',
#  'popularity': 586.767,
#  'poster_path': '/1Xgjl22MkAZQUavvOeBqRehrvqO.jpg',
#  'production_companies': [{'id': 127928,
#    'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#    'name': '20th Century Studios',
#    'origin_country': 'US'},
#   {'id': 1645,
#    'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#    'name': 'Scott Free Productions',
#    'origin_country': 'GB'},
#   {'id': 1557,
#    'logo_path': '/ccz9bqCu3jSFKbPFnfWmjAKZLBL.png',
#    'name': 'The Mark Gordon Company',
#    'origin_country': 'US'},
#   {'id': 28788,
#    'logo_path': None,
#    'name': 'Genre Films',
#    'origin_country': 'US'},
#   {'id': 84097,
#    'logo_path': '/bWEadFCSkNkyWJaw7cFbgxLwAs3.png',
#    'name': 'Agatha Christie Limited',
#    'origin_country': 'GB'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2023-09-13',
#  'revenue': 119000000,
#  'runtime': 104,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}],
#  'status': 'Released',
#  'tagline': 'Death was only the beginning.',
#  'title': 'A Haunting in Venice',
#  'video': False,
#  'vote_average': 6.827,
#  'vote_count': 954}

# %%
info['budget']
# Out:
# 60000000

# %%
info['revenue']
# Out:
# 119000000

# %%
info['imdb_id']
# Out:
# 'tt22687790'

# %%
# example from package README
# source = https://github.com/celiao/tmdbsimple
releases = movie.releases()
for c in releases['countries']:
    if c['iso_3166_1'] == 'US':
        print(c['certification'])
releases
# Out:
# PG-13
# PG-13
# PG-13
# {'id': 945729,
#  'countries': [{'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': 'TP',
#    'descriptors': [],
#    'iso_3166_1': 'FR',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ES',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '12',
#    'descriptors': ['Violence', 'Threat'],
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'UA',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'PG13',
#    'descriptors': [],
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'K-12',
#    'descriptors': [],
#    'iso_3166_1': 'FI',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '6+',
#    'descriptors': [],
#    'iso_3166_1': 'IT',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'U',
#    'descriptors': [],
#    'iso_3166_1': 'CZ',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'JP',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'TH',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PL',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '14',
#    'descriptors': [],
#    'iso_3166_1': 'BR',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'IIA',
#    'descriptors': [],
#    'iso_3166_1': 'HK',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KZ',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '12',
#    'descriptors': [],
#    'iso_3166_1': 'NO',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AR',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '16',
#    'descriptors': [],
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'B',
#    'descriptors': [],
#    'iso_3166_1': 'MX',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'NL',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PT',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CA',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'EE',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '12A',
#    'descriptors': [],
#    'iso_3166_1': 'GB',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'IN',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'IS',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': 'NR',
#    'descriptors': [],
#    'iso_3166_1': 'LT',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '15',
#    'descriptors': [],
#    'iso_3166_1': 'SE',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'TR',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CN',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '12+',
#    'descriptors': [],
#    'iso_3166_1': 'TW',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '12',
#    'descriptors': [],
#    'iso_3166_1': 'KR',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AT',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'PR',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'RO',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AL',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AG',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AW',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'BE',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'BA',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '15',
#    'descriptors': [],
#    'iso_3166_1': 'DK',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'BG',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'DO',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'VI',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'EC',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GP',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ID',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'LA',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'LU',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MA',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MC',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PH',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'RE',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AE',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AU',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '2023-09-13'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CH',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'CY',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GR',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GT',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'GY',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'HR',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '12',
#    'descriptors': [],
#    'iso_3166_1': 'IL',
#    'primary': False,
#    'release_date': '2023-09-21'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KN',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KW',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'LC',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'LV',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MD',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ME',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MK',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MY',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'OM',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PG',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'RS',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'SA',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'SI',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'SK',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'TT',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'XK',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '12A',
#    'descriptors': [],
#    'iso_3166_1': 'IE',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MG',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MT',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MV',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'PK',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'VN',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'ZA',
#    'primary': False,
#    'release_date': '2023-09-15'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'KH',
#    'primary': False,
#    'release_date': '2023-09-21'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'MN',
#    'primary': False,
#    'release_date': '2023-09-22'},
#   {'certification': 'B',
#    'descriptors': [],
#    'iso_3166_1': 'MO',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': '',
#    'descriptors': [],
#    'iso_3166_1': 'AZ',
#    'primary': False,
#    'release_date': '2023-09-14'},
#   {'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2023-10-31'},
#   {'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'PR',
#    'primary': False,
#    'release_date': '2023-10-31'},
#   {'certification': 'PG13',
#    'descriptors': [],
#    'iso_3166_1': 'SG',
#    'primary': False,
#    'release_date': '2023-10-31'},
#   {'certification': '16',
#    'descriptors': [],
#    'iso_3166_1': 'HU',
#    'primary': False,
#    'release_date': '2023-10-31'},
#   {'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'US',
#    'primary': False,
#    'release_date': '2023-11-28'},
#   {'certification': 'PG-13',
#    'descriptors': [],
#    'iso_3166_1': 'PR',
#    'primary': False,
#    'release_date': '2023-11-28'},
#   {'certification': '12',
#    'descriptors': [],
#    'iso_3166_1': 'DE',
#    'primary': False,
#    'release_date': '2023-12-15'},
#   {'certification': 'G',
#    'descriptors': [],
#    'iso_3166_1': 'JP',
#    'primary': False,
#    'release_date': '2024-01-17'},
#   {'certification': '6+',
#    'descriptors': [],
#    'iso_3166_1': 'IT',
#    'primary': False,
#    'release_date': '2023-12-13'}]}

# %%
# Get the movie object for the current id
movie = tmdb.Movies(945729)
# save the .info .releases dictionaries
info = movie.info()
releases = movie.releases()
# Loop through countries in releases
for c in releases['countries']:
    # if the country abbreviation==US
    if c['iso_3166_1' ] =='US':
        ## save a "certification" key in the info dict with the certification
       info['certification'] = c['certification']
info
# Out:
# {'adult': False,
#  'backdrop_path': '/kHlX3oqdD4VGaLpB8O78M25KfdS.jpg',
#  'belongs_to_collection': {'id': 735384,
#   'name': 'Hercule Poirot (Kenneth Branagh) Collection',
#   'poster_path': '/m9ypNb42ZKmwrHEsNxc329s1PI6.jpg',
#   'backdrop_path': '/rI27nF0juWNs3vwhQ8p2qUwE88F.jpg'},
#  'budget': 60000000,
#  'genres': [{'id': 9648, 'name': 'Mystery'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 80, 'name': 'Crime'}],
#  'homepage': 'https://www.20thcenturystudios.com/movies/a-haunting-in-venice',
#  'id': 945729,
#  'imdb_id': 'tt22687790',
#  'original_language': 'en',
#  'original_title': 'A Haunting in Venice',
#  'overview': 'Celebrated sleuth Hercule Poirot, now retired and living in self-imposed exile in Venice, reluctantly attends a Halloween séance at a decaying, haunted palazzo. When one of the guests is murdered, the detective is thrust into a sinister world of shadows and secrets.',
#  'popularity': 586.767,
#  'poster_path': '/1Xgjl22MkAZQUavvOeBqRehrvqO.jpg',
#  'production_companies': [{'id': 127928,
#    'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#    'name': '20th Century Studios',
#    'origin_country': 'US'},
#   {'id': 1645,
#    'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#    'name': 'Scott Free Productions',
#    'origin_country': 'GB'},
#   {'id': 1557,
#    'logo_path': '/ccz9bqCu3jSFKbPFnfWmjAKZLBL.png',
#    'name': 'The Mark Gordon Company',
#    'origin_country': 'US'},
#   {'id': 28788,
#    'logo_path': None,
#    'name': 'Genre Films',
#    'origin_country': 'US'},
#   {'id': 84097,
#    'logo_path': '/bWEadFCSkNkyWJaw7cFbgxLwAs3.png',
#    'name': 'Agatha Christie Limited',
#    'origin_country': 'GB'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2023-09-13',
#  'revenue': 119000000,
#  'runtime': 104,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}],
#  'status': 'Released',
#  'tagline': 'Death was only the beginning.',
#  'title': 'A Haunting in Venice',
#  'video': False,
#  'vote_average': 6.827,
#  'vote_count': 954,
#  'certification': 'PG-13'}

# %%
def get_movie_with_rating(movie_id):
    """Adapted from source = https://github.com/celiao/tmdbsimple"""
    
    # Get the movie object for the current id
    movie = tmdb.Movies(movie_id)
    
    # save the .info .releases dictionaries
    info = movie.info()

    releases = movie.releases()
    # Loop through countries in releases
    for c in releases['countries']:
        # if the country abbreviation==US
        if c['iso_3166_1' ] =='US':
            ## save a "certification" key in the info dict with the certification
           info['certification'] = c['certification']
        
    return info

# %%
test = get_movie_with_rating("945729")
test
# Out:
# {'adult': False,
#  'backdrop_path': '/kHlX3oqdD4VGaLpB8O78M25KfdS.jpg',
#  'belongs_to_collection': {'id': 735384,
#   'name': 'Hercule Poirot (Kenneth Branagh) Collection',
#   'poster_path': '/m9ypNb42ZKmwrHEsNxc329s1PI6.jpg',
#   'backdrop_path': '/rI27nF0juWNs3vwhQ8p2qUwE88F.jpg'},
#  'budget': 60000000,
#  'genres': [{'id': 9648, 'name': 'Mystery'},
#   {'id': 53, 'name': 'Thriller'},
#   {'id': 80, 'name': 'Crime'}],
#  'homepage': 'https://www.20thcenturystudios.com/movies/a-haunting-in-venice',
#  'id': 945729,
#  'imdb_id': 'tt22687790',
#  'original_language': 'en',
#  'original_title': 'A Haunting in Venice',
#  'overview': 'Celebrated sleuth Hercule Poirot, now retired and living in self-imposed exile in Venice, reluctantly attends a Halloween séance at a decaying, haunted palazzo. When one of the guests is murdered, the detective is thrust into a sinister world of shadows and secrets.',
#  'popularity': 586.767,
#  'poster_path': '/1Xgjl22MkAZQUavvOeBqRehrvqO.jpg',
#  'production_companies': [{'id': 127928,
#    'logo_path': '/h0rjX5vjW5r8yEnUBStFarjcLT4.png',
#    'name': '20th Century Studios',
#    'origin_country': 'US'},
#   {'id': 1645,
#    'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#    'name': 'Scott Free Productions',
#    'origin_country': 'GB'},
#   {'id': 1557,
#    'logo_path': '/ccz9bqCu3jSFKbPFnfWmjAKZLBL.png',
#    'name': 'The Mark Gordon Company',
#    'origin_country': 'US'},
#   {'id': 28788,
#    'logo_path': None,
#    'name': 'Genre Films',
#    'origin_country': 'US'},
#   {'id': 84097,
#    'logo_path': '/bWEadFCSkNkyWJaw7cFbgxLwAs3.png',
#    'name': 'Agatha Christie Limited',
#    'origin_country': 'GB'}],
#  'production_countries': [{'iso_3166_1': 'GB', 'name': 'United Kingdom'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2023-09-13',
#  'revenue': 119000000,
#  'runtime': 104,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'},
#   {'english_name': 'Italian', 'iso_639_1': 'it', 'name': 'Italiano'}],
#  'status': 'Released',
#  'tagline': 'Death was only the beginning.',
#  'title': 'A Haunting in Venice',
#  'video': False,
#  'vote_average': 6.827,
#  'vote_count': 954,
#  'certification': 'PG-13'}

# %%
## testing our function by looping through a list of ids
import pandas as pd
test_ids = ["tt0113026", "tt0113092","tt0115937","tt22687790"]
results = []
errors = []
for movie_id in test_ids:
    
    try:
        movie_info = get_movie_with_rating(movie_id)
        results.append(movie_info)
        
    except Exception as e:
        errors.append([movie_id,e])
    
    
pd.DataFrame(results)
# Out:
#    adult                     backdrop_path  \
# 0  False  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1  False                              None
# 2  False  /kHlX3oqdD4VGaLpB8O78M25KfdS.jpg
#
#                                belongs_to_collection    budget  \
# 0                                               None  10000000
# 1                                               None         0
# 2  {'id': 735384, 'name': 'Hercule Poirot (Kennet...  60000000
#
#                                               genres  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 1           [{'id': 878, 'name': 'Science Fiction'}]
# 2  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
#
#                                             homepage      id     imdb_id  \
# 0                                                      62127   tt0113026
# 1                                                     110977   tt0113092
# 2  https://www.20thcenturystudios.com/movies/a-ha...  945729  tt22687790
#
#   original_language        original_title  ...    revenue  runtime  \
# 0                en       The Fantasticks  ...          0       86
# 1                en         For the Cause  ...          0      100
# 2                en  A Haunting in Venice  ...  119000000      104
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                          tagline                 title  video  \
# 0  Try to remember the first time magic happened       The Fantasticks  False
# 1   The ultimate showdown on a forbidden planet.         For the Cause  False
# 2                  Death was only the beginning.  A Haunting in Venice  False
#
#    vote_average vote_count certification
# 0         5.500         22
# 1         5.450         10
# 2         6.824        958         PG-13
#
# [3 rows x 26 columns]

# %%
print(f"- Number of errors: {len(errors)}")
errors
# Out:
# - Number of errors: 1
# [['tt0115937',
#   requests.exceptions.HTTPError('404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/tt0115937?api_key=7cb985f81eeb5bcd4a0788e2b3b5a411')]]

# %%
import os, time,json
import tmdbsimple as tmdb 
FOLDER = "Data/"
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# []

# %%
def write_json(new_data, filename): 
    """Appends a list of records (new_data) to a json file (filename). 
    Adapted from: https://www.geeksforgeeks.org/append-to-json-file-using-python/"""  
    
    with open(filename,'r+') as file:
        # First we load existing data into a dict.
        file_data = json.load(file)
        ## Choose extend or append
        if (type(new_data) == list) & (type(file_data) == list):
            file_data.extend(new_data)
        else:
             file_data.append(new_data)
        # Sets file's current position at offset.
        file.seek(0)
        # convert back to json.
        json.dump(file_data, file)

# %%
# Load in the dataframe from project part 1 as basics:
basics = pd.read_csv("C:/Users/user/Documents/CodingDojo/Project-3-Part-1/Data/title_basics.csv.gz", low_memory = False)

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0082328     movie                                 Embodiment of Evil
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                      Encarnação do Demônio        0       2008      NaN
# 4                          The Naked Monster        0       2005      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3              94                  Horror
# 4             100    Comedy,Horror,Sci-Fi

# %%
YEARS_TO_GET = [2000]

# %%
errors = []

# %%
# Start of OUTER loop
for YEAR in tqdm(YEARS_TO_GET, desc='YEARS', position=0):2000
# Out:
# YEARS:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Defining the JSON file to store results for year
JSON_FILE = f'{FOLDER}tmdb_api_results_{YEAR}.json'

# %%
# Check if file exists
file_exists = os.path.isfile(JSON_FILE)

# %%
# If it does not exist: create it
if file_exists == False:
# save an empty dict with just "imdb_id" to the new json file.
    with open(JSON_FILE,'w') as f:
        json.dump([{'imdb_id':0}],f)

# %%
#Saving new year as the current df
df = basics.loc[ basics['startYear']==YEAR].copy()
# saving movie ids to list
movie_ids = df['tconst'].copy()

# %%
# Load existing data from json into a dataframe called "previous_df"
previous_df = pd.read_json(JSON_FILE)

# %%
# filter out any ids that are already in the JSON_FILE
movie_ids_to_get = movie_ids[~movie_ids.isin(previous_df['imdb_id'])]

# %%
    #Get index and movie id from list
    # INNER Loop
    for movie_id in tqdm(movie_ids_to_get,
                                  desc=f'Movies from {YEAR}',
                                  position=1,
                                  leave=True):
        try:
            # Retrieve then data for the movie id
            temp = get_movie_with_rating(movie_id)  
            # Append/extend results to existing file using a pre-made function
            write_json(temp,JSON_FILE)
            # Short 20 ms sleep to prevent overwhelming server
            time.sleep(0.02)
            
        except Exception as e:
            errors.append([movie_id, e])
# Out:
# Movies from 2000:   0%|          | 0/1466 [00:00<?, ?it/s]

# %%
    final_year_df = pd.read_json(JSON_FILE)
    final_year_df.to_csv(f"{FOLDER}final_tmdb_data_{YEAR}.csv.gz", compression="gzip", index=False)

# %%
print(f"- Total errors: {len(errors)}")
# Out:
# - Total errors: 232
